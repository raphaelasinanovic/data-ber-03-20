# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("../Data/good_reads_final_1.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  author_average_rating author_gender  \
# 0           0                   4.01        female
# 1           1                   4.15          male
# 2           2                   4.00        female
# 3           3                   3.88          male
# 4           4                   4.10        female
#
#                            author_genres  author_id          author_name  \
# 0                    historical-fiction,      74489    Victoria Thompson
# 1  literature-fiction,mystery-thrillers,     706255        Stieg Larsson
# 2                               romance,    5618190  Mimi Jean Pamfiloff
# 3                        fiction,memoir,      37871          José Donoso
# 4                   young-adult,fantasy,      36122    Patricia C. Wrede
#
#                             author_page_url  author_rating_count  \
# 0      /author/show/74489.Victoria_Thompson                74399
# 1         /author/show/706255.Stieg_Larsson              3726435
# ...

# %%
#change datatypes
df.dtypes
# Out:
# Unnamed: 0                 int64
# author_average_rating    float64
# author_gender             object
# author_genres             object
# author_id                  int64
# author_name               object
# author_page_url           object
# author_rating_count        int64
# author_review_count        int64
# birthplace                object
# book_average_rating      float64
# book_fullurl              object
# book_id                   object
# book_title                object
# genre_1                   object
# genre_2                   object
# num_ratings                int64
# num_reviews                int64
# pages                     object
# publish_date              object
# score                      int64
# dtype: object

# %%
#remove nulls

# %%
#rename columns

# %%
df["author_name"]=df["author_name"].str.replace("\n","")

# %%
df.head()
# Out:
#    Unnamed: 0  author_average_rating author_gender  \
# 0           0                   4.01        female
# 1           1                   4.15          male
# 2           2                   4.00        female
# 3           3                   3.88          male
# 4           4                   4.10        female
#
#                            author_genres  author_id          author_name  \
# 0                    historical-fiction,      74489    Victoria Thompson
# 1  literature-fiction,mystery-thrillers,     706255        Stieg Larsson
# 2                               romance,    5618190  Mimi Jean Pamfiloff
# 3                        fiction,memoir,      37871          José Donoso
# 4                   young-adult,fantasy,      36122    Patricia C. Wrede
#
#                             author_page_url  author_rating_count  \
# 0      /author/show/74489.Victoria_Thompson                74399
# 1         /author/show/706255.Stieg_Larsson              3726435
# ...

# %%
df["birthplace"]=df["birthplace"].str.replace("\n","")

# %%
df["book_title"]=df["book_title"].str.replace("\n","")

# %%
df.head()
# Out:
#    Unnamed: 0  author_average_rating author_gender  \
# 0           0                   4.01        female
# 1           1                   4.15          male
# 2           2                   4.00        female
# 3           3                   3.88          male
# 4           4                   4.10        female
#
#                            author_genres  author_id          author_name  \
# 0                    historical-fiction,      74489    Victoria Thompson
# 1  literature-fiction,mystery-thrillers,     706255        Stieg Larsson
# 2                               romance,    5618190  Mimi Jean Pamfiloff
# 3                        fiction,memoir,      37871          José Donoso
# 4                   young-adult,fantasy,      36122    Patricia C. Wrede
#
#                             author_page_url  author_rating_count  \
# 0      /author/show/74489.Victoria_Thompson                74399
# 1         /author/show/706255.Stieg_Larsson              3726435
# ...

# %%
df["publish_date"]=df["publish_date"].str.split().tolist()[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-ba64b4e8f85a> in <module>
# ----> 1 df["publish_date"]=df["publish_date"].str.split().tolist()[-1]
#
# ~/opt/anaconda2/envs/backpack_banana/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# ~/opt/anaconda2/envs/backpack_banana/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2998
#    2999         self._ensure_valid_index(value)
# -> 3000         value = self._sanitize_column(key, value)
#    3001         NDFrame._set_item(self, key, value)
#    3002
#
# ...

# %%
df.to_csv("../Data/good_reads_final_1.csv")

# %%
df[["author_rating_count"]].describe()
# Out:
#        author_rating_count
# count         2.289100e+04
# mean          1.720319e+05
# std           6.546902e+05
# min           6.000000e+00
# 25%           4.324500e+03
# 50%           2.463500e+04
# 75%           1.113370e+05
# max           2.111732e+07

# %%
#max=21.117.318 =2.111732e+07? (2.111732 * 10**7)
#min=6=6.000000e+00
#rows: 2.289100e+04 = 22.892

# %%
df.count
# Out:
# <bound method DataFrame.count of        Unnamed: 0  author_average_rating author_gender  \
# 0               0                   4.01        female
# 1               1                   4.15          male
# 2               2                   4.00        female
# 3               3                   3.88          male
# 4               4                   4.10        female
# ...           ...                    ...           ...
# 22886       22886                   3.94        female
# 22887       22887                   4.29          male
# 22888       22888                   4.00        female
# 22889       22889                   4.20        female
# 22890       22890                   4.07          male
#
#                                author_genres  author_id          author_name  \
# 0                        historical-fiction,      74489    Victoria Thompson
# 1      literature-fiction,mystery-thrillers,     706255        Stieg Larsson
# ...

# %%
            
df = df.drop(df[df.author_rating_count < 100000].index)

# %%
df.count
# Out:
# <bound method DataFrame.count of        Unnamed: 0  author_average_rating author_gender  \
# 1               1                   4.15          male
# 4               4                   4.10        female
# 6               6                   4.16        female
# 7               7                   3.94        female
# 9               9                   4.08        female
# ...           ...                    ...           ...
# 22710       22710                   4.30        female
# 22794       22794                   3.89        female
# 22860       22860                   4.33        female
# 22861       22861                   4.26          male
# 22875       22875                   4.02        female
#
#                                author_genres  author_id        author_name  \
# 1      literature-fiction,mystery-thrillers,     706255      Stieg Larsson
# 4                       young-adult,fantasy,      36122  Patricia C. Wrede
# ...

# %%
df = df.drop(df[df.author_rating_count < 200000].index)

# %%
df.count
# Out:
# <bound method DataFrame.count of        Unnamed: 0  author_average_rating author_gender  \
# 1               1                   4.15          male
# 4               4                   4.10        female
# 7               7                   3.94        female
# 9               9                   4.08        female
# 10             10                   4.39          male
# ...           ...                    ...           ...
# 22228       22228                   3.76        female
# 22244       22244                   4.01          male
# 22458       22458                   3.86        female
# 22697       22697                   4.11          male
# 22861       22861                   4.26          male
#
#                                author_genres  author_id        author_name  \
# 1      literature-fiction,mystery-thrillers,     706255      Stieg Larsson
# 4                       young-adult,fantasy,      36122  Patricia C. Wrede
# ...

# %%
df = df.drop(df[df.author_average_rating < 4].index)

# %%
df.count
# Out:
# <bound method DataFrame.count of        Unnamed: 0  author_average_rating author_gender  \
# 1               1                   4.15          male
# 4               4                   4.10        female
# 9               9                   4.08        female
# 10             10                   4.39          male
# 12             12                   4.03        female
# ...           ...                    ...           ...
# 22155       22155                   4.43          male
# 22183       22183                   4.45        female
# 22244       22244                   4.01          male
# 22697       22697                   4.11          male
# 22861       22861                   4.26          male
#
#                                author_genres  author_id        author_name  \
# 1      literature-fiction,mystery-thrillers,     706255      Stieg Larsson
# 4                       young-adult,fantasy,      36122  Patricia C. Wrede
# ...

# %%
df = df.drop(df[df.author_average_rating < 4].index)

# %%
df.count
# Out:
# <bound method DataFrame.count of        Unnamed: 0  author_average_rating author_gender  \
# 544           544                   4.55        female
# 1292         1292                   4.55        female
# 1968         1968                   4.67          male
# 3898         3898                   4.55        female
# 4088         4088                   4.67          male
# 4819         4819                   4.55        female
# 7268         7268                   4.67          male
# 8846         8846                   4.55        female
# 12199       12199                   4.67          male
# 14285       14285                   4.67          male
# 17050       17050                   4.55        female
# 19328       19328                   4.55        female
#
#                      author_genres  author_id     author_name  \
# 544    manga,fantasy,contemporary,    4698899  Hiromu Arakawa
# 1292                  young-adult,   15049422    Angie Thomas
# ...
